# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
import matplotlib as plt
import seaborn as sns
from lxml import html

# %%
df_1= pd.read_csv('..\data\Graph_of_Excise_Taxes_on_Cigarettes__CDC_STATE_System_Tobacco_Legislation_-_Tax_.csv')

df_1
# Out:
#       Year  Quarter LocationAbbr LocationDesc  \
# 0     2021        1           MD     Maryland
# 1     2021        2           MD     Maryland
# 2     2021        4           VA     Virginia
# 3     2016        1           UT         Utah
# 4     2016        3           MT      Montana
# ...    ...      ...          ...          ...
# 4579  2021        3           NM   New Mexico
# 4580  2019        3           NM   New Mexico
# 4581  2020        3           NM   New Mexico
# 4582  2020        4           NM   New Mexico
# 4583  2021        4           NM   New Mexico
#
#                                   TopicDesc MeasureDesc DataSource  \
# 0     Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 1     Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 2     Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 3     Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 4     Legislation - Tax Combustible Tobacco   Cigarette        OSH
# ...                                     ...         ...        ...
# 4579  Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 4580  Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 4581  Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 4582  Legislation - Tax Combustible Tobacco   Cigarette        OSH
# 4583  Legislation - Tax Combustible Tobacco   Cigarette        OSH
#
#      ProvisionGroupDesc               ProvisionDesc ProvisionValue  ...  \
# 0          Restrictions  Cigarette Tax ($ per pack)          3.750  ...
# 1          Restrictions  Cigarette Tax ($ per pack)          3.750  ...
# 2          Restrictions  Cigarette Tax ($ per pack)          0.600  ...
# 3          Restrictions  Cigarette Tax ($ per pack)          1.700  ...
# 4          Restrictions  Cigarette Tax ($ per pack)          1.700  ...
# ...                 ...                         ...            ...  ...
# 4579       Restrictions  Cigarette Tax ($ per pack)          2.000  ...
# 4580       Restrictions  Cigarette Tax ($ per pack)          2.000  ...
# 4581       Restrictions  Cigarette Tax ($ per pack)          2.000  ...
# 4582       Restrictions  Cigarette Tax ($ per pack)          2.000  ...
# 4583       Restrictions  Cigarette Tax ($ per pack)          2.000  ...
#
#      Comments  Enacted_Date Effective_Date  \
# 0         NaN     2/12/2021      3/14/2021
# 1         NaN     2/12/2021      3/14/2021
# 2         NaN     5/21/2020       7/1/2020
# 3         NaN     3/13/2010       7/1/2010
# 4         NaN     11/2/2004       1/1/2005
# ...       ...           ...            ...
# 4579      NaN      4/4/2019       7/1/2019
# 4580      NaN      4/4/2019       7/1/2019
# 4581      NaN      4/4/2019       7/1/2019
# 4582      NaN      4/4/2019       7/1/2019
# 4583      NaN      4/4/2019       7/1/2019
#
#                                     GeoLocation DisplayOrder TopicTypeId  \
# 0       (39.29058096400047, -76.60926011099963)            5         LEG
# 1       (39.29058096400047, -76.60926011099963)            5         LEG
# 2       (37.54268067400045, -78.45789046299967)            5         LEG
# 3     (39.360700171000474, -111.58713063499971)            5         LEG
# 4      (47.06652897200047, -109.42442064499971)            5         LEG
# ...                                         ...          ...         ...
# 4579   (34.52088095200048, -106.24058098499967)            5         LEG
# 4580   (34.52088095200048, -106.24058098499967)            5         LEG
# 4581   (34.52088095200048, -106.24058098499967)            5         LEG
# 4582   (34.52088095200048, -106.24058098499967)            5         LEG
# 4583   (34.52088095200048, -106.24058098499967)            5         LEG
#
#       TopicId  MeasureId ProvisionGroupID ProvisionID
# 0     1010LEG     670CGR            10GRP         411
# 1     1010LEG     670CGR            10GRP         411
# 2     1010LEG     670CGR            10GRP         411
# 3     1010LEG     670CGR            10GRP         411
# 4     1010LEG     670CGR            10GRP         411
# ...       ...        ...              ...         ...
# 4579  1010LEG     670CGR            10GRP         411
# 4580  1010LEG     670CGR            10GRP         411
# 4581  1010LEG     670CGR            10GRP         411
# 4582  1010LEG     670CGR            10GRP         411
# 4583  1010LEG     670CGR            10GRP         411
#
# [4584 rows x 23 columns]

# %%
df_2= pd.read_csv('..\data\BRFSS_Prevalence_and_Trends_Data__Tobacco_Use_-_Four_Level_Smoking_Data_for_1995-2010.csv')
df_2
# Out:
#      Year           State  Smoke everyday  Smoke some days  Former smoker  \
# 0    1996     Puerto Rico             9.4              5.1           16.0
# 1    2005  Virgin Islands             5.3              2.8           12.8
# 2    2005     Puerto Rico             7.9              5.2           16.9
# 3    2002  Virgin Islands             7.0              2.4           12.1
# 4    2003            Guam            26.3              7.8           14.3
# ..    ...             ...             ...              ...            ...
# 871  1995      Washington            17.5              2.4           29.9
# 872  1995        Virginia            18.7              2.7           25.2
# 873  2004    North Dakota            14.8              5.1           23.6
# 874  2005    Rhode Island            15.3              4.4           28.8
# 875  2005      New Mexico            14.6              6.9           24.4
#
#      Never smoked                                         Location 1
# 0            69.5                                        Puerto Rico
# 1            79.1                                     Virgin Islands
# 2            70.0                                        Puerto Rico
# 3            78.5                                     Virgin Islands
# 4            51.7                                                NaN
# ..            ...                                                ...
# 871          50.2  Washington\n(47.522280000022135, -120.47001000...
# 872          53.5  Virginia\n(37.54268000028196, -78.45789000012326)
# 873          56.5  North Dakota\n(47.475320000018144, -100.118419...
# 874          51.4  Rhode Island\n(41.70828000002217, -71.52247000...
# 875          54.1  New Mexico\n(34.52088000011207, -106.240579999...
#
# [876 rows x 7 columns]

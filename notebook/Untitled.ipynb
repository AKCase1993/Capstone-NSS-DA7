# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
import matplotlib as plt
import seaborn as sns
from lxml import html

# %%
df_1= pd.read_csv('..\data\BRFSS_Prevalence_and_Trends_Data__Tobacco_Use_-_Four_Level_Smoking_Data_for_1995-2010.csv')
df_1
# Out:
#      Year           State  Smoke everyday  Smoke some days  Former smoker  \
# 0    1996     Puerto Rico             9.4              5.1           16.0
# 1    2005  Virgin Islands             5.3              2.8           12.8
# 2    2005     Puerto Rico             7.9              5.2           16.9
# 3    2002  Virgin Islands             7.0              2.4           12.1
# 4    2003            Guam            26.3              7.8           14.3
# ..    ...             ...             ...              ...            ...
# 871  1995      Washington            17.5              2.4           29.9
# 872  1995        Virginia            18.7              2.7           25.2
# 873  2004    North Dakota            14.8              5.1           23.6
# 874  2005    Rhode Island            15.3              4.4           28.8
# 875  2005      New Mexico            14.6              6.9           24.4
#
#      Never smoked                                         Location 1
# 0            69.5                                        Puerto Rico
# 1            79.1                                     Virgin Islands
# 2            70.0                                        Puerto Rico
# 3            78.5                                     Virgin Islands
# 4            51.7                                                NaN
# ..            ...                                                ...
# 871          50.2  Washington\n(47.522280000022135, -120.47001000...
# 872          53.5  Virginia\n(37.54268000028196, -78.45789000012326)
# 873          56.5  North Dakota\n(47.475320000018144, -100.118419...
# 874          51.4  Rhode Island\n(41.70828000002217, -71.52247000...
# 875          54.1  New Mexico\n(34.52088000011207, -106.240579999...
#
# [876 rows x 7 columns]

# %%
df_2= pd.read_csv('..\data\enforcement-of-bans-on-tobacco-advertising.csv')
df_2
# Out:
#            Entity Code  Year  Indicator:Enforce bans on tobacco advertising
# 0     Afghanistan  AFG  2007                                              4
# 1     Afghanistan  AFG  2008                                              4
# 2     Afghanistan  AFG  2010                                              4
# 3     Afghanistan  AFG  2012                                              4
# 4     Afghanistan  AFG  2014                                              4
# ...           ...  ...   ...                                            ...
# 1360     Zimbabwe  ZWE  2010                                              2
# 1361     Zimbabwe  ZWE  2012                                              2
# 1362     Zimbabwe  ZWE  2014                                              2
# 1363     Zimbabwe  ZWE  2016                                              2
# 1364     Zimbabwe  ZWE  2018                                              2
#
# [1365 rows x 4 columns]

# %%
df_3= pd.read_csv('..\data\share-of-tobacco-retail-price-that-is-tax.csv')
df_3
# Out:
#            Entity Code  Year  Indicator:Raise taxes on tobacco
# 0     Afghanistan  AFG  2008                                 2
# 1     Afghanistan  AFG  2010                                 2
# 2     Afghanistan  AFG  2012                                 2
# 3     Afghanistan  AFG  2014                                 2
# 4     Afghanistan  AFG  2016                                 2
# ...           ...  ...   ...                               ...
# 1153     Zimbabwe  ZWE  2010                                 4
# 1154     Zimbabwe  ZWE  2012                                 3
# 1155     Zimbabwe  ZWE  2014                                 3
# 1156     Zimbabwe  ZWE  2016                                 3
# 1157     Zimbabwe  ZWE  2018                                 3
#
# [1158 rows x 4 columns]

# %%
df_4= pd.read_csv('..\data\smoking-death-rate-1990-2017.csv')
df_4
# Out:
#              Entity      Code  Year  \
# 0          Abkhazia  OWID_ABK  2015
# 1       Afghanistan       AFG  1990
# 2       Afghanistan       AFG  1991
# 3       Afghanistan       AFG  1992
# 4       Afghanistan       AFG  1993
# ...             ...       ...   ...
# 6916       Zimbabwe       ZWE  2016
# 6917       Zimbabwe       ZWE  2017
# 6918       Zimbabwe       ZWE  2018
# 6919       Zimbabwe       ZWE  2019
# 6920  Åland Islands       ALA  2015
#
#       Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                   NaN
# 1                                                 75.84
# 2                                                 75.64
# 3                                                 75.66
# 4                                                 76.53
# ...                                                 ...
# 6916                                             140.49
# 6917                                             138.10
# 6918                                             135.94
# 6919                                             134.16
# 6920                                                NaN
#
#      Continent  \
# 0         Asia
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 6916       NaN
# 6917       NaN
# 6918       NaN
# 6919       NaN
# 6920    Europe
#
#       Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: Age-standardized (Rate).1  \
# 0                                                   NaN
# 1                                                 81.75
# 2                                                 81.75
# 3                                                 81.75
# 4                                                 81.75
# ...                                                 ...
# 6916                                             134.16
# 6917                                             134.16
# 6918                                             134.16
# 6919                                             134.16
# 6920                                                NaN
#
#       Year.1
# 0        NaN
# 1     2019.0
# 2     2019.0
# 3     2019.0
# 4     2019.0
# ...      ...
# 6916  2019.0
# 6917  2019.0
# 6918  2019.0
# 6919  2019.0
# 6920     NaN
#
# [6921 rows x 7 columns]

# %%
countries_df= pd.merge(df_2,df_3,how='left',on=['Entity', 'Year'])

countries_df
# Out:
#            Entity Code_x  Year  Indicator:Enforce bans on tobacco advertising  \
# 0     Afghanistan    AFG  2007                                              4
# 1     Afghanistan    AFG  2008                                              4
# 2     Afghanistan    AFG  2010                                              4
# 3     Afghanistan    AFG  2012                                              4
# 4     Afghanistan    AFG  2014                                              4
# ...           ...    ...   ...                                            ...
# 1360     Zimbabwe    ZWE  2010                                              2
# 1361     Zimbabwe    ZWE  2012                                              2
# 1362     Zimbabwe    ZWE  2014                                              2
# 1363     Zimbabwe    ZWE  2016                                              2
# 1364     Zimbabwe    ZWE  2018                                              2
#
#      Code_y  Indicator:Raise taxes on tobacco
# 0       NaN                               NaN
# 1       AFG                               2.0
# 2       AFG                               2.0
# 3       AFG                               2.0
# 4       AFG                               2.0
# ...     ...                               ...
# 1360    ZWE                               4.0
# 1361    ZWE                               3.0
# 1362    ZWE                               3.0
# 1363    ZWE                               3.0
# 1364    ZWE                               3.0
#
# [1365 rows x 6 columns]

# %%
countries_df_1= pd.merge(countries_df,df_4,how='left',on=['Entity', 'Year'])

countries_df_1
# Out:
#            Entity Code_x  Year  Indicator:Enforce bans on tobacco advertising  \
# 0     Afghanistan    AFG  2007                                              4
# 1     Afghanistan    AFG  2008                                              4
# 2     Afghanistan    AFG  2010                                              4
# 3     Afghanistan    AFG  2012                                              4
# 4     Afghanistan    AFG  2014                                              4
# ...           ...    ...   ...                                            ...
# 1360     Zimbabwe    ZWE  2010                                              2
# 1361     Zimbabwe    ZWE  2012                                              2
# 1362     Zimbabwe    ZWE  2014                                              2
# 1363     Zimbabwe    ZWE  2016                                              2
# 1364     Zimbabwe    ZWE  2018                                              2
#
#      Code_y  Indicator:Raise taxes on tobacco Code  \
# 0       NaN                               NaN  AFG
# 1       AFG                               2.0  AFG
# 2       AFG                               2.0  AFG
# 3       AFG                               2.0  AFG
# 4       AFG                               2.0  AFG
# ...     ...                               ...  ...
# 1360    ZWE                               4.0  ZWE
# 1361    ZWE                               3.0  ZWE
# 1362    ZWE                               3.0  ZWE
# 1363    ZWE                               3.0  ZWE
# 1364    ZWE                               3.0  ZWE
#
#       Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                 79.44
# 1                                                 79.74
# 2                                                 79.72
# 3                                                 80.20
# 4                                                 80.72
# ...                                                 ...
# 1360                                             158.00
# 1361                                             150.48
# 1362                                             144.08
# 1363                                             140.49
# 1364                                             135.94
#
#      Continent  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1360       NaN
# 1361       NaN
# 1362       NaN
# 1363       NaN
# 1364       NaN
#
#       Deaths - Cause: All causes - Risk: Smoking - Sex: Both - Age: Age-standardized (Rate).1  \
# 0                                                 81.75
# 1                                                 81.75
# 2                                                 81.75
# 3                                                 81.75
# 4                                                 81.75
# ...                                                 ...
# 1360                                             134.16
# 1361                                             134.16
# 1362                                             134.16
# 1363                                             134.16
# 1364                                             134.16
#
#       Year.1
# 0     2019.0
# 1     2019.0
# 2     2019.0
# 3     2019.0
# 4     2019.0
# ...      ...
# 1360  2019.0
# 1361  2019.0
# 1362  2019.0
# 1363  2019.0
# 1364  2019.0
#
# [1365 rows x 11 columns]

# %%
countries_df_1.to_csv(r'C:\Users\Andrew\Desktop\DA7/Projects/Capstone-NSS-DA7/data/country_ds.csv', index = False)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
import matplotlib as plt
import seaborn as sns
from lxml import html

# %%
who_df= pd.read_csv('..\data\Who_workbook.csv',  encoding='latin1')
who_df
# Out:
#                                 Country Price 2014 Affordability Change 2014  \
# 0                           Afghanistan          0                         0
# 1                               Albania          2                         3
# 2                               Algeria          1                         0
# 3                               Andorra          .                         5
# 4                                Angola          1                         1
# ..                                  ...        ...                       ...
# 190  Venezuela (Bolivarian Republic of)          .                         1
# 191                            Viet Nam          1                        0*
# 192                               Yemen          .                         4
# 193                              Zambia          1                        0*
# 194                            Zimbabwe          1                         0
#
#     Tax Share 2014 Tax Structure 2014 Overall Score 2014 Price 2016  \
# 0                0                  0                  0          0
# 1              2.5                  4               2.88          2
# 2              0.5                  1               0.63          2
# 3                4                  1                  .          .
# 4                0                  0                0.5          .
# ..             ...                ...                ...        ...
# 190              4                  .                  .          .
# 191              0                  2               0.75          1
# 192              1                  4                  .          .
# 193              0                  2               0.75          2
# 194            0.5                  4               1.38          1
#
#     Affordability Change 2016 Tax Share 2016 Tax Structure 2016  ...  \
# 0                           1              0                  0  ...
# 1                           3              3                  4  ...
# 2                           5            0.5                  1  ...
# 3                           0            4.5                  1  ...
# 4                           0              .                  .  ...
# ..                        ...            ...                ...  ...
# 190                         1              4                  2  ...
# 191                         0            0.5                  2  ...
# 192                         5              1                  1  ...
# 193                         0            0.5                  2  ...
# 194                         5            0.5                  4  ...
#
#     Price 2018 Affordability Change 2018 Tax Share 2018 Tax Structure 2018  \
# 0            0                         1              0                  0
# 1            2                         0              3                  4
# 2            3                         5              0                  1
# 3            .                         0              5                  4
# 4            1                         1              0                  0
# ..         ...                       ...            ...                ...
# 190          .                         1              4                  2
# 191          1                         0            0.5                  2
# 192          .                         5              1                  4
# 193          1                         0            0.5                  2
# 194          0                         0            0.5                  4
#
#     Overall Score 2018 Price 2020 Affordability Change 2020 Tax Share 2020  \
# 0                 0.25          0                         0              0
# 1                 2.25          3                         0            3.5
# 2                 2.25          3                         5            0.5
# 3                    .          .                        0*              5
# 4                  0.5          2                         5              0
# ..                 ...        ...                       ...            ...
# 190                  .          .                         1              4
# 191               0.88          1                        0*              1
# 192                  .          .                         5              1
# 193               0.88          1                         0            0.5
# 194               1.13          2                         0              0
#
#     Tax Structure 2020 Overall Score 2020
# 0                    0                  0
# 1                    5               2.88
# 2                    1               2.38
# 3                    4                  .
# 4                    2               2.25
# ..                 ...                ...
# 190                  .                  .
# 191                  2                  1
# 192                  4                  .
# 193                  4               1.38
# 194                  3               1.25
#
# [195 rows x 21 columns]
